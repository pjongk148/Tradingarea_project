# %%
import  numpy as np
import pandas as pd
import  matplotlib.pyplot as plt


#그래프에 한글 표현하기
import  matplotlib.font_manager as fm
font_name = fm.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family = font_name)

#마이너스 표시하기
import  matplotlib as mlp
mlp.rcParams["axes.unicode_minus"]  = False


import  seaborn as sns

import folium

# %%
df = pd.read_csv("전처리완성본/지역화페 전처리 완성본.csv")
df = df[df["동명"]=="영통동"]

# %%
df =df.reset_index(drop=True)
df
# Out:
#                     상호명          업종명   업종대분류 업종소분류  \
# 0               (주)로얄부페  일반휴게음식-일반한식  일반휴게음식  일반한식
# 1              (주)에베레스트  일반휴게음식-서양음식  일반휴게음식  서양음식
# 2      (주)에스앤제이푸드 죠스떡볶이    일반휴게음식-스넥  일반휴게음식    스넥
# 3     (주)에스앤제이푸드 지니스테이블  일반휴게음식-일반한식  일반휴게음식  일반한식
# 4    (주)우헌/천보헌갈비마을(영통점)  일반휴게음식-일반한식  일반휴게음식  일반한식
# ..                  ...          ...     ...   ...
# 978           커피브라더 영통점  일반휴게음식-서양음식  일반휴게음식  서양음식
# 979              태백실비식당  일반휴게음식-일반한식  일반휴게음식  일반한식
# 980              태백실비식당  일반휴게음식-일반한식  일반휴게음식  일반한식
# 981               파주옥곰탕  일반휴게음식-일반한식  일반휴게음식  일반한식
# 982        피자스쿨 영통중심상가점  일반휴게음식-서양음식  일반휴게음식  서양음식
#
#                                       소재지도로명주소  \
# 0            경기 수원시 영통구 영통동1009-3효원빌딩501호,601호
# 1             경기 수원시 영통구 청명남로 50,2층 (영통동,문원빌딩)
# 2          경기 수원시 영통구 덕영대로 1566지하1층 101호 (영통동)
# 3               경기 수원시 영통구 덕영대로 1566, 3층 (영통동)
# 4             경기 수원시 영통구 매영로 390(영통동) 104-113호
# ..                                         ...
# ...

# %%
map = folium.Map(location=[37.251077, 127.075972], zoom_start=15)



for i in range(len(df)):
    marker = folium.Marker(location=[df.loc[i,"위도"], df.loc[i,"경도"]],
                      icon = folium.Icon(color = "red", icon="star"),
                      popup = df.loc[i,"상호명"]).add_to(map)
    
    

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df.loc[1,"위도"]
# Out:
# 37.2538119526

# %%
df["업종소분류"] = df["업종소분류"].str.replace("?","")

# %%
df["업종소분류"].unique()
# Out:
# array(['일반한식', '서양음식', '스넥', '주점', '일식회집', '중국식', '칵테일바'], dtype=object)

# %%
for i in list(df["업종소분류"].unique()):
    globals()["df_{}".format(i)] = df[df["업종소분류"]==i].reset_index(drop=True)

# %%
df_스넥
# Out:
#                  상호명        업종명   업종대분류 업종소분류  \
# 0   (주)에스앤제이푸드 죠스떡볶이  일반휴게음식-스넥  일반휴게음식    스넥
# 1             (주)티엔씨  일반휴게음식-스넥  일반휴게음식    스넥
# 2              60계치킨  일반휴게음식-스넥  일반휴게음식    스넥
# 3         가마로강정 망포역점  일반휴게음식-스넥  일반휴게음식    스넥
# 4          감탄(영통2호점)  일반휴게음식-스넥  일반휴게음식    스넥
# ..               ...        ...     ...   ...
# 83     호치킨 수원영통청명마을점  일반휴게음식-스넥  일반휴게음식    스넥
# 84          홍루이젠 영통점  일반휴게음식-스넥  일반휴게음식    스넥
# 85  홍마떡 망포역점 홍대마늘떡볶이  일반휴게음식-스넥  일반휴게음식    스넥
# 86         후라이드참잘하는집  일반휴게음식-스넥  일반휴게음식    스넥
# 87      히어로보드게임카페영통점  일반휴게음식-스넥  일반휴게음식    스넥
#
#                                            소재지도로명주소  \
# 0               경기 수원시 영통구 덕영대로 1566지하1층 101호 (영통동)
# 1                   경기 수원시 영통구 청명로 7청명타운텔 114호(영통동)
# 2                   경기 수원시 영통구 영일로 25,1층 101호 (영통동)
# 3                 경기 수원시 영통구 덕영대로1555번길 13106호(영통동)
# 4      경기 수원시 영통구 봉영로1770번길 21(영통동,신명.한국아파트상가 123호)
# ..                                              ...
# ...

# %%
map = folium.Map(location=[37.251077, 127.075972], zoom_start=15)

tab = df_중국식
abl = df_일식회집
ble = df_스넥
ack= df_서양음식

#원 거리 150m로 고정
folium.Circle(location = [37.264634, 127.077676],
                    radius = 150, color = "#ffffgg", fill_color = "#fffggg").add_to(map)


for i in range(len(tab)):
    marker = folium.CircleMarker(location=[tab.loc[i,"위도"], tab.loc[i,"경도"]],
                      radius = 7,color = "red",fill=True,fill_color="red",
                      popup =tab.loc[i,"상호명"]).add_to(map)
    

    
for i in range(len(abl)):
    marker = folium.CircleMarker(location=[abl.loc[i,"위도"], abl.loc[i,"경도"]],
                      radius = 7,color = "blue",fill=True,fill_color="blue",
                      popup =abl.loc[i,"상호명"]).add_to(map)   
    
    
for i in range(len(ble)):
    marker = folium.CircleMarker(location=[ble.loc[i,"위도"], ble.loc[i,"경도"]],
                      radius = 7,color = "yellow",fill=True,fill_color="yellow",
                      popup =ble.loc[i,"상호명"]).add_to(map)   
    
# for i in range(len(ack)):
#     marker = folium.CircleMarker(location=[ack.loc[i,"위도"], ack.loc[i,"경도"]],
#                       radius = 5,color = "black",fill=True,fill_color="black",
#                       popup =ack.loc[i,"상호명"]).add_to(map)  





map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map.save('전처리완성본/지도.html')
